# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql://postgres:arielle89@localhost:5432/Team8')

# %%
df_test_cleaned = pd.read_sql_query('select * from "test_cleaned"', con=engine)
df_train_cleaned = pd.read_sql_query('select * from "train_cleaned"', con=engine)

# %%
df_test_cleaned
# Out:
#      house_id overallqual yearbuilt yearremodadd masvnrarea bsmtfinsf1  \
# 0           0           5      1961         1961        0.0      468.0
# 1           1           6      1958         1958      108.0      923.0
# 2           2           5      1997         1998        0.0      791.0
# 3           3           6      1998         1998       20.0      602.0
# 4           4           8      1992         1992        0.0      263.0
# ...       ...         ...       ...          ...        ...        ...
# 1454     1454           4      1970         1970        0.0        0.0
# 1455     1455           4      1970         1970        0.0      252.0
# 1456     1456           5      1960         1996        0.0     1224.0
# 1457     1457           5      1992         1992        0.0      337.0
# 1458     1458           7      1993         1994       94.0      758.0
#
#      totalbsmtsf firstflrsf secflrsf grlivarea fullbath totrmsabvgrd  \
# ...

# %%
df_train_cleaned
# Out:
#      house_id overallqual yearbuilt yearremodadd masvnrarea bsmtfinsf1  \
# 0           0           7      2003         2003      196.0        706
# 1           1           6      1976         1976        0.0        978
# 2           2           7      2001         2002      162.0        486
# 3           3           7      1915         1970        0.0        216
# 4           4           8      2000         2000      350.0        655
# ...       ...         ...       ...          ...        ...        ...
# 1453     1455           6      1999         2000        0.0          0
# 1454     1456           6      1978         1988      119.0        790
# 1455     1457           7      1941         2006        0.0        275
# 1456     1458           5      1950         1996        0.0         49
# 1457     1459           5      1965         1965        0.0        830
#
#      totalbsmtsf firstflrsf secflrsf grlivarea fullbath totrmsabvgrd  \
# ...
